# %%
import cv2
import numpy as np

# %%
def nothing(x):
    pass

#cv2.namedWindow('Tracking')

while(True):
    frame = cv2.imread('smarties.png')
    # now convert to hsv image
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    #now threshold the hsv image for blue color
    l_b = np.array([110,50,50]) #first define the lower range
    u_b = np.array([130,255,255]) #then the upper range
    
    mask = cv2.inRange(hsv,l_b, u_b) #masking only select the region between u_b and l_b
    
    #now bitwise_and operation which will be 1 when the two are similar
    res = cv2.bitwise_and(frame, frame, mask=mask)
    
    cv2.imshow('frame', frame)
    cv2.imshow('Mask', mask)
    cv2.imshow('Result', res)
    
    k = cv2.waitKey(1) & 0xFF
    if k == 27:
        break
cv2.destroyAllWindows()

# %% [markdown]
# ### Using trackbar to detect object

# %%
def nothing(x):
    pass

cv2.namedWindow('Tracking')
cv2.createTrackbar('LH','Tracking', 0, 359, nothing)
cv2.createTrackbar('LS','Tracking', 0, 255, nothing)
cv2.createTrackbar('LV','Tracking', 0, 255, nothing)
cv2.createTrackbar('UH','Tracking', 0, 359, nothing)
cv2.createTrackbar('US','Tracking', 0, 255, nothing)
cv2.createTrackbar('UV','Tracking', 0, 255, nothing)

while(True):
    
    frame = cv2.imread('smarties.png')
    # now convert to hsv image
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
        
    lh = cv2.getTrackbarPos('LH','Tracking')
    ls = cv2.getTrackbarPos('LS','Tracking')
    lv = cv2.getTrackbarPos('LV','Tracking')
    uh = cv2.getTrackbarPos('UH','Tracking')
    us = cv2.getTrackbarPos('US','Tracking')
    uv = cv2.getTrackbarPos('UV','Tracking')
    
    #now threshold the hsv image for any color
    l = np.array([lh,ls,lv]) #first define the lower range
    u = np.array([uh,us,uv]) #then the upper range
    
    mask = cv2.inRange(hsv,l, u) #masking only select the region between u_b and l_b
    
    #now bitwise_and operation which will be 1 when the two are similar
    res = cv2.bitwise_and(frame, frame, mask=mask)
    
    cv2.imshow('frame', frame)
    cv2.imshow('Mask', mask)
    cv2.imshow('Result', res)
    
    k = cv2.waitKey(1) & 0xFF
    if k == 27:
        break
cv2.destroyAllWindows()

# %% [markdown]
# ### Object Detection in video

# %%
def nothing(x):
    pass

cap= cv2.VideoCapture(0)

cv2.namedWindow('Tracking')
cv2.createTrackbar('LH','Tracking', 0, 255, nothing)
cv2.createTrackbar('LS','Tracking', 0, 255, nothing)
cv2.createTrackbar('LV','Tracking', 0, 255, nothing)
cv2.createTrackbar('UH','Tracking', 0, 359, nothing)
cv2.createTrackbar('US','Tracking', 0, 255, nothing)
cv2.createTrackbar('UV','Tracking', 0, 255, nothing)

while(True):
    
    ret,frame = cap.read()
    # now convert to hsv image
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
        
    lh = cv2.getTrackbarPos('LH','Tracking')
    ls = cv2.getTrackbarPos('LS','Tracking')
    lv = cv2.getTrackbarPos('LV','Tracking')
    uh = cv2.getTrackbarPos('UH','Tracking')
    us = cv2.getTrackbarPos('US','Tracking')
    uv = cv2.getTrackbarPos('UV','Tracking')
    
    #now threshold the hsv image for any color
    l = np.array([lh,ls,lv]) #first define the lower range
    u = np.array([uh,us,uv]) #then the upper range
    
    mask = cv2.inRange(hsv,l, u) #masking only select the region between u_b and l_b
    
    #now bitwise_and operation which will be 1 when the two are similar
    res = cv2.bitwise_and(frame, frame, mask=mask)
    
    cv2.imshow('frame', frame)
    cv2.imshow('Mask', mask)
    cv2.imshow('Result', res)
    
    k = cv2.waitKey(1) & 0xFF
    if k == 27:
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ###  Self Practice

# %%
while(True):
    frame = cv2.imread('smarties.png')
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    l_b = np.array([110,50,50])
    u_b = np.array([130,255,255])
    
    mask = cv2.inRange(hsv, l_b, u_b)
    
    final = cv2.bitwise_and(frame,frame,mask=mask)
    
    cv2.imshow('Original',frame)
    cv2.imshow('Mask',mask)
    cv2.imshow('Final',final)
    
    if cv2.waitKey(1) & 0xFF == 27:
        break
cv2.destroyAllWindows()

# %%
def nothing(x):
    pass

cv2.namedWindow('Original')

cv2.createTrackbar('LH','Original', 0, 359, nothing)
cv2.createTrackbar('LS','Original', 0, 255, nothing)
cv2.createTrackbar('LV','Original', 0, 255, nothing)
cv2.createTrackbar('UH','Original', 0, 359, nothing)
cv2.createTrackbar('US','Original', 0, 255, nothing)
cv2.createTrackbar('UV','Original', 0, 255, nothing)

while(True):
    frame = cv2.imread('smarties.png')
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    lh = cv2.getTrackbarPos('LH', 'Original')
    ls = cv2.getTrackbarPos('LS', 'Original')
    lv = cv2.getTrackbarPos('LV', 'Original')
    uh = cv2.getTrackbarPos('UH', 'Original')
    us = cv2.getTrackbarPos('US', 'Original')
    uv = cv2.getTrackbarPos('UV', 'Original')
    
    l_b = np.array([lh,ls,lv])
    u_b = np.array([uh,us,uv])
    
    mask = cv2.inRange(hsv, l_b, u_b)
    
    final = cv2.bitwise_and(frame,frame,mask=mask)
    
    cv2.imshow('Frame',frame)
    cv2.imshow('Mask',mask)
    cv2.imshow('Final',final)
    
    if cv2.waitKey(1) & 0xFF == 27:
        break
cv2.destroyAllWindows()

# %%
def nothing(x):
    pass

cv2.namedWindow('Original')
cap = cv2.VideoCapture(0)

cv2.createTrackbar('LH','Original', 0, 359, nothing)
cv2.createTrackbar('LS','Original', 0, 255, nothing)
cv2.createTrackbar('LV','Original', 0, 255, nothing)
cv2.createTrackbar('UH','Original', 0, 359, nothing)
cv2.createTrackbar('US','Original', 0, 255, nothing)
cv2.createTrackbar('UV','Original', 0, 255, nothing)

while(True):
    ret,frame = cap.read()
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    lh = cv2.getTrackbarPos('LH', 'Original')
    ls = cv2.getTrackbarPos('LS', 'Original')
    lv = cv2.getTrackbarPos('LV', 'Original')
    uh = cv2.getTrackbarPos('UH', 'Original')
    us = cv2.getTrackbarPos('US', 'Original')
    uv = cv2.getTrackbarPos('UV', 'Original')
    
    l_b = np.array([lh,ls,lv])
    u_b = np.array([uh,us,uv])
    
    mask = cv2.inRange(hsv, l_b, u_b)
    
    final = cv2.bitwise_and(frame,frame,mask=mask)
    
    cv2.imshow('Frame',frame)
    cv2.imshow('Mask',mask)
    cv2.imshow('Final',final)
    
    if cv2.waitKey(1) & 0xFF == 27:
        break
cap.release()
cv2.destroyAllWindows()
